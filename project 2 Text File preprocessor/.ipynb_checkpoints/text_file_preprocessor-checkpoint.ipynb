# %% [markdown]
# A program that reads text files
# removes punctuation
# converts to lowercase
# removes extra spaces
# saves cleaned text to new file.

# %%
import re

def read_txt_file(text_file):

    try:
        with open(text_file,'r',encoding = 'utf-8') as f:
            text = f.read()
    except FileNotFoundError:
        print(f"{text_file} File Not Found")
        return 

    # remove punctuation 
    cleaned = re.sub(r'[^\w\s]','',text) # this will only allow \w-> words, \s-> spaces in text other will be removed with "" which is nothing

    # removes extra spaces
    cleaned = cleaned.strip()

    # save clear text 
    with open('cleaned_text.txt','w',encoding = 'utf-8') as f:
        f.write(cleaned)

    return cleaned
    
read_txt_file("text.txt")
# Out:
# This is my SECOND project
# I want to CLEAN some text maybe Or maybe not
#
# Anyway here is some RANDOM text
# Python is AWESOME or is it
# Numbers 10 20 30 40 50
#
# Wait Why are there so many spaces
# Why_are_there_underscores_here
# Special chars _  should be removed
#
# THIS LINE HAS TOO MANY SPACES
# this Line Has MiXeD CaSe And extra SPACES
#
# End of file Maybe not
# One more line before we END

# %%
cleaned = re.sub(r'[^\w\s]','',text)
